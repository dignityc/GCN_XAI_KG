# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
import wandb, os
sampling_size = 10000
batch_size = 16384
os.environ['WANDB_WATCH'] = 'all'
wandb.login(key = "d737480c1d812ca4c1c791b14b0888051f72b45a")
wandb.init(name="testing_from-jongmo",
           project="GCN-recommendaiton",
           tags=['for_testing_in_A100_80gb'],
           group=f"Sample_size:{sampling_size}"
           )
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing last run (ID:v3eo4eo8) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>70.13124</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">testing_from-jongmo</strong> at: <a href='https://wandb.ai/jjj1234/GCN-recommendaiton/runs/v3eo4eo8' target="_blank">https://wandb.ai/jjj1234/GCN-recommendaiton/runs/v3eo4eo8</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231025_135859-v3eo4eo8/logs</code>
# Successfully finished last run (ID:v3eo4eo8). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/scratch/users/k2369089/SKKU/wandb/run-20231025_142317-n3sxgb82</code>
# Syncing run <strong><a href='https://wandb.ai/jjj1234/GCN-recommendaiton/runs/n3sxgb82' target="_blank">testing_from-jongmo</a></strong> to <a href='https://wandb.ai/jjj1234/GCN-recommendaiton' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jjj1234/GCN-recommendaiton' target="_blank">https://wandb.ai/jjj1234/GCN-recommendaiton</a>
#  View run at <a href='https://wandb.ai/jjj1234/GCN-recommendaiton/runs/n3sxgb82' target="_blank">https://wandb.ai/jjj1234/GCN-recommendaiton/runs/n3sxgb82</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/jjj1234/GCN-recommendaiton/runs/n3sxgb82?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
class InteractionDataset(Dataset):
    def __init__(self, positive_users, positive_items, negative_items):
        assert len(positive_users) == len(positive_items) == len(negative_items)
        self.positive_users = positive_users
        self.positive_items = positive_items
        self.negative_items = negative_items

    def __len__(self):
        return len(self.positive_users)

    def __getitem__(self, idx):
        return self.positive_users[idx], self.positive_items[idx], self.negative_items[idx]


class GraphConvolutionLayer(nn.Module):
    def __init__(self, in_features, out_features):
        super(GraphConvolutionLayer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.FloatTensor(in_features, out_features))
        nn.init.xavier_uniform_(self.weight)

    def forward(self, input, adj):
        support = torch.mm(input, self.weight)
        output = torch.mm(adj, support)
        return output
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, embedding_dim):
        super(GCN, self).__init__()
        self.gc1 = GraphConvolutionLayer(input_dim, hidden_dim)
        self.gc2 = GraphConvolutionLayer(hidden_dim, embedding_dim)

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = self.gc2(x, adj)
        return x
class BPRLoss(nn.Module):
    def __init__(self):
        super(BPRLoss, self).__init__()

    def forward(self, positive_scores, negative_scores):
        loss = -torch.sum(F.logsigmoid(positive_scores - negative_scores))
        return loss

# %%
#Data prep.
ui = pd.read_csv('final/final_ui_interaction.csv')
ie = pd.read_csv('final/final_ie_interaction.csv')
ui = ui[['userID', 'itemID']].sample(sampling_size)
ie = ie[['itemID', 'entityID']].sample(sampling_size)
# 1. 유니크한 사용자, 아이템, 엔터티 리스트 생성
unique_users = ui['userID'].unique()
unique_items = pd.concat([ui['itemID'], ie['itemID']]).unique()  # ui와 ie에서 아이템 가져오기
unique_entities = ie['entityID'].unique()

# 2. 새로운 ID 부여
user_to_id = {user: idx for idx, user in enumerate(unique_users)}
item_to_id = {item: idx + len(unique_users) for idx, item in enumerate(unique_items)}  # 사용자 수만큼 오프셋
entity_to_id = {entity: idx + len(unique_users) + len(unique_items) for idx, entity in enumerate(unique_entities)}

# 3. 새로운 ID로 데이터 업데이트
ui['userID'] = ui['userID'].map(user_to_id)
ui['itemID'] = ui['itemID'].map(item_to_id)
ie['itemID'] = ie['itemID'].map(item_to_id)
ie['entityID'] = ie['entityID'].map(entity_to_id)

# 4. 인접 행렬 생성
num_total_nodes = len(unique_users) + len(unique_items) + len(unique_entities)
adj_matrix = np.zeros((num_total_nodes, num_total_nodes))

# ui 상호작용 추가
for _, row in ui.iterrows():
    adj_matrix[row['userID'], row['itemID']] = 1
    adj_matrix[row['itemID'], row['userID']] = 1

# ie 상호작용 추가
for _, row in ie.iterrows():
    adj_matrix[row['itemID'], row['entityID']] = 1
    adj_matrix[row['entityID'], row['itemID']] = 1

# 결과 리턴: 새로운 ID 부여된 데이터와 인접행렬
new_ui = ui
new_ie = ie
total_nodes_length = len(unique_users) + len(unique_items) + len(unique_entities)

# new_ui, new_ie, adj_matrix 를 사용

# %%
import random

# 긍정적 유저-아이템 데이터 추출
positive_samples = new_ui.reset_index(drop=True)
positive_users = positive_samples['userID'].tolist()
positive_items = positive_samples['itemID'].tolist()

# 부정적 유저-아이템 데이터 생성
all_items = set(new_ui['itemID'].unique())
negative_users = []
negative_items = []

while len(negative_users) < sampling_size:
    random_user = random.choice(positive_users)
    random_item = random.choice(list(all_items))

    # 해당 유저가 해당 아이템과 상호작용하지 않았을 경우만 부정적 데이터로 추가
    if not new_ui[(new_ui['userID'] == random_user) & (new_ui['itemID'] == random_item)].empty:
        continue

    negative_users.append(random_user)
    negative_items.append(random_item)

print(len(positive_users), len(positive_items), len(negative_items))
# Out:
# 10000 10000 10000

# %%
num_nodes = total_nodes_length
node_features = torch.eye(num_nodes)  # One-Hot 인코딩
epochs = 1000
dataset = InteractionDataset(positive_users, positive_items, negative_items)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
node_features = torch.FloatTensor(node_features)
node_features = node_features.to(device)
adj = torch.FloatTensor(adj_matrix)
adj = adj.to(device)
model = GCN(input_dim=node_features.size(1), hidden_dim=64, embedding_dim=32)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

bpr_loss = BPRLoss()

# %%
# Group by userID and aggregate itemIDs into sets
grouped = ui.groupby('userID')['itemID'].apply(set)

# Convert the grouped Series into a dictionary
ground_truth = grouped.to_dict()

# %%
def generate_recommendations(model, node_features, adj, user_ids, num_recommendations):
    model.eval()
    with torch.no_grad():
        embeddings = model(node_features, adj)
    recommendations = {}
    # Correcting the range of item_ids
    item_ids = torch.arange(len(unique_users), len(unique_users) + len(unique_items)).to(device)
    for user_id in user_ids:
        # Ensure user_id is within valid range
        if user_id >= len(unique_users):
            print(f'Skipping user_id {user_id} as it is out of bounds')
            continue
        scores = torch.sum(embeddings[user_id] * embeddings[item_ids], dim=1)
        _, top_indices = torch.topk(scores, num_recommendations)
        recommended_items = [item_ids[i].item() for i in top_indices]  # Converting tensor indices to Python integers
        recommendations[user_id] = set(recommended_items)
    return recommendations



def calculate_recall(recommendations, ground_truth):
    total_relevant_items = 0
    total_recommended_relevant_items = 0
    for user_id, recommended_items in recommendations.items():
        relevant_items = ground_truth.get(user_id, set())
        total_relevant_items += len(relevant_items)
        total_recommended_relevant_items += len(relevant_items.intersection(recommended_items))
    recall = total_recommended_relevant_items / total_relevant_items if total_relevant_items > 0 else 0
    return recall

# %%
for epoch in range(epochs):
    model.train()
    total_loss = 0.0

    for batch_users, batch_pos_items, batch_neg_items in dataloader:
        batch_users = batch_users.to(device)
        batch_pos_items = batch_pos_items.to(device)
        batch_neg_items = batch_neg_items.to(device)        
        
        optimizer.zero_grad()

        embeddings = model(node_features, adj)
        
        positive_scores = torch.sum(embeddings[batch_users] * embeddings[batch_pos_items], dim=1)
        negative_scores = torch.sum(embeddings[batch_users] * embeddings[batch_neg_items], dim=1)

        loss = bpr_loss(positive_scores, negative_scores)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        user_ids = list(unique_users)
        num_recommendations = 10
        recommendations = generate_recommendations(model, node_features, adj, user_ids, num_recommendations)
        recall = calculate_recall(recommendations, ground_truth)
        
    Loss = total_loss / len(dataloader)
    wandb.log({"train_loss": Loss})
    print(f"Epoch {epoch + 1}, Loss: {Loss}, Recall:{recall}")
# Out:
# Skipping user_id 9718 as it is out of bounds
# Skipping user_id 20421 as it is out of bounds
# Skipping user_id 9938 as it is out of bounds
# Skipping user_id 14768 as it is out of bounds
# Skipping user_id 28081 as it is out of bounds
# Skipping user_id 19522 as it is out of bounds
# Skipping user_id 14034 as it is out of bounds
# Skipping user_id 13141 as it is out of bounds
# Skipping user_id 25213 as it is out of bounds
# Skipping user_id 19365 as it is out of bounds
# Skipping user_id 17377 as it is out of bounds
# Skipping user_id 18869 as it is out of bounds
# Skipping user_id 8022 as it is out of bounds
# Skipping user_id 10084 as it is out of bounds
# Skipping user_id 21988 as it is out of bounds
# Skipping user_id 25898 as it is out of bounds
# Skipping user_id 18986 as it is out of bounds
# Skipping user_id 21210 as it is out of bounds
# Skipping user_id 24862 as it is out of bounds
# Skipping user_id 12209 as it is out of bounds
# Skipping user_id 24817 as it is out of bounds
# Skipping user_id 12866 as it is out of bounds
# Skipping user_id 7326 as it is out of bounds
# Skipping user_id 11286 as it is out of bounds
# Skipping user_id 16051 as it is out of bounds
# Skipping user_id 22708 as it is out of bounds
# Skipping user_id 6797 as it is out of bounds
# Skipping user_id 12391 as it is out of bounds
# Skipping user_id 8781 as it is out of bounds
# Skipping user_id 13445 as it is out of bounds
# Skipping user_id 15776 as it is out of bounds
# Skipping user_id 19607 as it is out of bounds
# Skipping user_id 27232 as it is out of bounds
# Skipping user_id 18536 as it is out of bounds
# Skipping user_id 27797 as it is out of bounds
# Skipping user_id 25979 as it is out of bounds
# Skipping user_id 26200 as it is out of bounds
# Skipping user_id 23531 as it is out of bounds
# Skipping user_id 12882 as it is out of bounds
# Skipping user_id 23053 as it is out of bounds
# Skipping user_id 18233 as it is out of bounds
# Skipping user_id 13794 as it is out of bounds
# Skipping user_id 12883 as it is out of bounds
# Skipping user_id 9236 as it is out of bounds
# Skipping user_id 11251 as it is out of bounds
# Skipping user_id 18597 as it is out of bounds
# Skipping user_id 18721 as it is out of bounds
# Skipping user_id 6988 as it is out of bounds
# Skipping user_id 27741 as it is out of bounds
# Skipping user_id 21659 as it is out of bounds
# Skipping user_id 22409 as it is out of bounds
# Skipping user_id 25626 as it is out of bounds
# Skipping user_id 13591 as it is out of bounds
# Skipping user_id 27597 as it is out of bounds
# Skipping user_id 6900 as it is out of bounds
# Skipping user_id 25680 as it is out of bounds
# Skipping user_id 26152 as it is out of bounds
# Skipping user_id 20787 as it is out of bounds
# Skipping user_id 14047 as it is out of bounds
# Skipping user_id 9507 as it is out of bounds
# Skipping user_id 12603 as it is out of bounds
# Skipping user_id 11769 as it is out of bounds
# Skipping user_id 26694 as it is out of bounds
# Skipping user_id 12605 as it is out of bounds
# Skipping user_id 26487 as it is out of bounds
# Skipping user_id 8656 as it is out of bounds
# Skipping user_id 12341 as it is out of bounds
# Skipping user_id 27222 as it is out of bounds
# Skipping user_id 15235 as it is out of bounds
# Skipping user_id 9276 as it is out of bounds
# Skipping user_id 9660 as it is out of bounds
# Skipping user_id 15693 as it is out of bounds
# Skipping user_id 7341 as it is out of bounds
# Skipping user_id 19991 as it is out of bounds
# Skipping user_id 26502 as it is out of bounds
# Skipping user_id 13823 as it is out of bounds
# Skipping user_id 16869 as it is out of bounds
# Skipping user_id 20252 as it is out of bounds
# Skipping user_id 27733 as it is out of bounds
# Skipping user_id 22149 as it is out of bounds
# Skipping user_id 10529 as it is out of bounds
# Skipping user_id 11582 as it is out of bounds
# Skipping user_id 9437 as it is out of bounds
# Skipping user_id 18535 as it is out of bounds
# Skipping user_id 21552 as it is out of bounds
# Skipping user_id 9920 as it is out of bounds
# Skipping user_id 13412 as it is out of bounds
# Skipping user_id 20134 as it is out of bounds
# Skipping user_id 18351 as it is out of bounds
# Skipping user_id 8998 as it is out of bounds
# Skipping user_id 20073 as it is out of bounds
# Skipping user_id 20298 as it is out of bounds
# Skipping user_id 20889 as it is out of bounds
# Skipping user_id 26220 as it is out of bounds
# Skipping user_id 6762 as it is out of bounds
# Skipping user_id 11056 as it is out of bounds
# Skipping user_id 17027 as it is out of bounds
# Skipping user_id 18167 as it is out of bounds
# Skipping user_id 8578 as it is out of bounds
# Skipping user_id 12907 as it is out of bounds
# Skipping user_id 8553 as it is out of bounds
# Skipping user_id 10474 as it is out of bounds
# Skipping user_id 15734 as it is out of bounds
# Skipping user_id 22564 as it is out of bounds
# Skipping user_id 17035 as it is out of bounds
# Skipping user_id 11368 as it is out of bounds
# Skipping user_id 8706 as it is out of bounds
# Skipping user_id 9928 as it is out of bounds
# Skipping user_id 12910 as it is out of bounds
# Skipping user_id 12857 as it is out of bounds
# Skipping user_id 21939 as it is out of bounds
# Skipping user_id 27969 as it is out of bounds
# Skipping user_id 22440 as it is out of bounds
# Skipping user_id 19093 as it is out of bounds
# Skipping user_id 19056 as it is out of bounds
# Skipping user_id 7809 as it is out of bounds
# Skipping user_id 8227 as it is out of bounds
# Skipping user_id 24729 as it is out of bounds
# Skipping user_id 11902 as it is out of bounds
# Skipping user_id 18382 as it is out of bounds
# Skipping user_id 22432 as it is out of bounds
# Skipping user_id 11111 as it is out of bounds
# Skipping user_id 8210 as it is out of bounds
# Skipping user_id 17298 as it is out of bounds
# Skipping user_id 14027 as it is out of bounds
# Skipping user_id 21022 as it is out of bounds
# Skipping user_id 15673 as it is out of bounds
# Skipping user_id 25596 as it is out of bounds
# Skipping user_id 6945 as it is out of bounds
# Skipping user_id 26482 as it is out of bounds
# Skipping user_id 21347 as it is out of bounds
# Skipping user_id 24212 as it is out of bounds
# Skipping user_id 11192 as it is out of bounds
# Skipping user_id 24946 as it is out of bounds
# Skipping user_id 20291 as it is out of bounds
# Skipping user_id 27217 as it is out of bounds
# Skipping user_id 10578 as it is out of bounds
# Skipping user_id 15796 as it is out of bounds
# Skipping user_id 13080 as it is out of bounds
# Skipping user_id 11547 as it is out of bounds
# Skipping user_id 22035 as it is out of bounds
# Skipping user_id 16552 as it is out of bounds
# Skipping user_id 28161 as it is out of bounds
# Skipping user_id 12567 as it is out of bounds
# Skipping user_id 27305 as it is out of bounds
# Skipping user_id 26961 as it is out of bounds
# Skipping user_id 8658 as it is out of bounds
# Skipping user_id 24445 as it is out of bounds
# Skipping user_id 21549 as it is out of bounds
# Skipping user_id 22493 as it is out of bounds
# Skipping user_id 11352 as it is out of bounds
# Skipping user_id 20763 as it is out of bounds
# Skipping user_id 15638 as it is out of bounds
# Skipping user_id 14462 as it is out of bounds
# Skipping user_id 8782 as it is out of bounds
# Skipping user_id 13337 as it is out of bounds
# Skipping user_id 19292 as it is out of bounds
# Skipping user_id 21487 as it is out of bounds
# Skipping user_id 9579 as it is out of bounds
# Skipping user_id 17363 as it is out of bounds
# Skipping user_id 13721 as it is out of bounds
# Skipping user_id 8372 as it is out of bounds
# Skipping user_id 9892 as it is out of bounds
# Skipping user_id 24113 as it is out of bounds
# Skipping user_id 11257 as it is out of bounds
# Skipping user_id 26536 as it is out of bounds
# Skipping user_id 12249 as it is out of bounds
# Skipping user_id 22080 as it is out of bounds
# Skipping user_id 21915 as it is out of bounds
# Skipping user_id 7523 as it is out of bounds
# Skipping user_id 11254 as it is out of bounds
# Skipping user_id 22919 as it is out of bounds
# Skipping user_id 7599 as it is out of bounds
# Skipping user_id 16357 as it is out of bounds
# Skipping user_id 28431 as it is out of bounds
# Skipping user_id 7912 as it is out of bounds
# Skipping user_id 15667 as it is out of bounds
# Skipping user_id 27498 as it is out of bounds
# Skipping user_id 21374 as it is out of bounds
# Skipping user_id 14344 as it is out of bounds
# Skipping user_id 16032 as it is out of bounds
# Skipping user_id 7193 as it is out of bounds
# Skipping user_id 7637 as it is out of bounds
# Skipping user_id 18374 as it is out of bounds
# Skipping user_id 18576 as it is out of bounds
# Skipping user_id 27347 as it is out of bounds
# Skipping user_id 21120 as it is out of bounds
# Skipping user_id 14573 as it is out of bounds
# Skipping user_id 20675 as it is out of bounds
# Skipping user_id 11007 as it is out of bounds
# Skipping user_id 22903 as it is out of bounds
# Skipping user_id 11465 as it is out of bounds
# Skipping user_id 19736 as it is out of bounds
# Skipping user_id 10855 as it is out of bounds
# Skipping user_id 11740 as it is out of bounds
# Skipping user_id 16633 as it is out of bounds
# Skipping user_id 21092 as it is out of bounds
# Skipping user_id 24167 as it is out of bounds
# Skipping user_id 10749 as it is out of bounds
# Skipping user_id 18894 as it is out of bounds
# Skipping user_id 22276 as it is out of bounds
# Skipping user_id 26846 as it is out of bounds
# Skipping user_id 13192 as it is out of bounds
# Skipping user_id 13814 as it is out of bounds
# Skipping user_id 23985 as it is out of bounds
# Skipping user_id 28014 as it is out of bounds
# Skipping user_id 15730 as it is out of bounds
# Skipping user_id 6776 as it is out of bounds
# Skipping user_id 20571 as it is out of bounds
# Skipping user_id 23020 as it is out of bounds
# Skipping user_id 16003 as it is out of bounds
# Skipping user_id 28850 as it is out of bounds
# Skipping user_id 17014 as it is out of bounds
# Skipping user_id 14668 as it is out of bounds
# Skipping user_id 25660 as it is out of bounds
# Skipping user_id 7105 as it is out of bounds
# Skipping user_id 18931 as it is out of bounds
# Skipping user_id 26340 as it is out of bounds
# Skipping user_id 10923 as it is out of bounds
# Skipping user_id 19927 as it is out of bounds
# Skipping user_id 18491 as it is out of bounds
# Skipping user_id 24042 as it is out of bounds
# Skipping user_id 19850 as it is out of bounds
# Skipping user_id 24612 as it is out of bounds
# Skipping user_id 26247 as it is out of bounds
# Skipping user_id 8044 as it is out of bounds
# Skipping user_id 16572 as it is out of bounds
# Skipping user_id 24711 as it is out of bounds
# Skipping user_id 8301 as it is out of bounds
# Skipping user_id 24251 as it is out of bounds
# Skipping user_id 24260 as it is out of bounds
# Skipping user_id 18949 as it is out of bounds
# Skipping user_id 22898 as it is out of bounds
# Skipping user_id 21167 as it is out of bounds
# Skipping user_id 16026 as it is out of bounds
# Skipping user_id 26493 as it is out of bounds
# Skipping user_id 14043 as it is out of bounds
# Skipping user_id 17792 as it is out of bounds
# Skipping user_id 10043 as it is out of bounds
# Skipping user_id 22711 as it is out of bounds
# Skipping user_id 9247 as it is out of bounds
# Skipping user_id 28379 as it is out of bounds
# Skipping user_id 26215 as it is out of bounds
# Skipping user_id 13841 as it is out of bounds
# Skipping user_id 11513 as it is out of bounds
# Skipping user_id 26475 as it is out of bounds
# Skipping user_id 19786 as it is out of bounds
# Skipping user_id 19641 as it is out of bounds
# Skipping user_id 20780 as it is out of bounds
# Skipping user_id 28335 as it is out of bounds
# Skipping user_id 13084 as it is out of bounds
# Skipping user_id 7412 as it is out of bounds
# Skipping user_id 17973 as it is out of bounds
# Skipping user_id 19737 as it is out of bounds
# Skipping user_id 8004 as it is out of bounds
# Skipping user_id 28271 as it is out of bounds
# Skipping user_id 17919 as it is out of bounds
# Skipping user_id 27082 as it is out of bounds
# Skipping user_id 22225 as it is out of bounds
# Skipping user_id 15081 as it is out of bounds
# Skipping user_id 24302 as it is out of bounds
# Skipping user_id 17905 as it is out of bounds
# Skipping user_id 26332 as it is out of bounds
# Skipping user_id 28077 as it is out of bounds
# Skipping user_id 13132 as it is out of bounds
# Skipping user_id 9841 as it is out of bounds
# Skipping user_id 13195 as it is out of bounds
# Skipping user_id 27050 as it is out of bounds
# Skipping user_id 22561 as it is out of bounds
# Skipping user_id 16060 as it is out of bounds
# Skipping user_id 21908 as it is out of bounds
# Skipping user_id 11089 as it is out of bounds
# Skipping user_id 17239 as it is out of bounds
# Skipping user_id 13258 as it is out of bounds
# Skipping user_id 10299 as it is out of bounds
# Skipping user_id 20110 as it is out of bounds
# Skipping user_id 17853 as it is out of bounds
# Skipping user_id 13750 as it is out of bounds
# Skipping user_id 13698 as it is out of bounds
# Skipping user_id 17119 as it is out of bounds
# Skipping user_id 13501 as it is out of bounds
# Skipping user_id 13526 as it is out of bounds
# Skipping user_id 27311 as it is out of bounds
# Skipping user_id 11826 as it is out of bounds
# Skipping user_id 8504 as it is out of bounds
# Skipping user_id 7746 as it is out of bounds
# Skipping user_id 24538 as it is out of bounds
# Skipping user_id 25347 as it is out of bounds
# Skipping user_id 18807 as it is out of bounds
# Skipping user_id 17041 as it is out of bounds
# Skipping user_id 16985 as it is out of bounds
# Skipping user_id 19173 as it is out of bounds
# Skipping user_id 24467 as it is out of bounds
# Skipping user_id 12969 as it is out of bounds
# Skipping user_id 15926 as it is out of bounds
# Skipping user_id 9879 as it is out of bounds
# Skipping user_id 7979 as it is out of bounds
# Skipping user_id 25218 as it is out of bounds
# Skipping user_id 7179 as it is out of bounds
# Skipping user_id 16328 as it is out of bounds
# Skipping user_id 7866 as it is out of bounds
# Skipping user_id 9555 as it is out of bounds
# Skipping user_id 17555 as it is out of bounds
# Skipping user_id 22346 as it is out of bounds
# Skipping user_id 18985 as it is out of bounds
# Skipping user_id 27083 as it is out of bounds
# Skipping user_id 14936 as it is out of bounds
# Skipping user_id 17968 as it is out of bounds
# Skipping user_id 10937 as it is out of bounds
# Skipping user_id 9980 as it is out of bounds
# Skipping user_id 28228 as it is out of bounds
# Skipping user_id 19320 as it is out of bounds
# Skipping user_id 14866 as it is out of bounds
# Skipping user_id 16786 as it is out of bounds
# Skipping user_id 15675 as it is out of bounds
# Skipping user_id 26132 as it is out of bounds
# Skipping user_id 13892 as it is out of bounds
# Skipping user_id 28818 as it is out of bounds
# Skipping user_id 8761 as it is out of bounds
# Skipping user_id 9559 as it is out of bounds
# Skipping user_id 20126 as it is out of bounds
# Skipping user_id 15199 as it is out of bounds
# Skipping user_id 15741 as it is out of bounds
# Skipping user_id 13880 as it is out of bounds
# Skipping user_id 19412 as it is out of bounds
# Skipping user_id 18919 as it is out of bounds
# Skipping user_id 16019 as it is out of bounds
# Skipping user_id 25764 as it is out of bounds
# Skipping user_id 26611 as it is out of bounds
# Skipping user_id 11596 as it is out of bounds
# Skipping user_id 23898 as it is out of bounds
# Skipping user_id 20975 as it is out of bounds
# Skipping user_id 23590 as it is out of bounds
# Skipping user_id 19211 as it is out of bounds
# Skipping user_id 6918 as it is out of bounds
# Skipping user_id 11250 as it is out of bounds
# Skipping user_id 9525 as it is out of bounds
# Skipping user_id 16533 as it is out of bounds
# Skipping user_id 20835 as it is out of bounds
# Skipping user_id 24284 as it is out of bounds
# Skipping user_id 11551 as it is out of bounds
# Skipping user_id 17637 as it is out of bounds
# Skipping user_id 26696 as it is out of bounds
# Skipping user_id 23850 as it is out of bounds
# Skipping user_id 25864 as it is out of bounds
# Skipping user_id 22508 as it is out of bounds
# Skipping user_id 23819 as it is out of bounds
# Skipping user_id 11053 as it is out of bounds
# Skipping user_id 26704 as it is out of bounds
# Skipping user_id 27878 as it is out of bounds
# Skipping user_id 8207 as it is out of bounds
# Skipping user_id 9910 as it is out of bounds
# Skipping user_id 19848 as it is out of bounds
# Skipping user_id 16070 as it is out of bounds
# Skipping user_id 17762 as it is out of bounds
# Skipping user_id 10900 as it is out of bounds
# Skipping user_id 26843 as it is out of bounds
# Skipping user_id 21477 as it is out of bounds
# Skipping user_id 8353 as it is out of bounds
# Skipping user_id 9489 as it is out of bounds
# Skipping user_id 22170 as it is out of bounds
# Skipping user_id 24900 as it is out of bounds
# Skipping user_id 23118 as it is out of bounds
# Skipping user_id 25748 as it is out of bounds
# Skipping user_id 18054 as it is out of bounds
# Skipping user_id 16663 as it is out of bounds
# Skipping user_id 11175 as it is out of bounds
# Skipping user_id 25648 as it is out of bounds
# Skipping user_id 7558 as it is out of bounds
# Skipping user_id 10267 as it is out of bounds
# Skipping user_id 11361 as it is out of bounds
# Skipping user_id 26415 as it is out of bounds
# Skipping user_id 22592 as it is out of bounds
# Skipping user_id 14170 as it is out of bounds
# Skipping user_id 15928 as it is out of bounds
# Skipping user_id 12126 as it is out of bounds
# Skipping user_id 27234 as it is out of bounds
# Skipping user_id 21216 as it is out of bounds
# Skipping user_id 28519 as it is out of bounds
# Skipping user_id 17157 as it is out of bounds
# Skipping user_id 23861 as it is out of bounds
# Skipping user_id 8430 as it is out of bounds
# Skipping user_id 16597 as it is out of bounds
# Skipping user_id 25060 as it is out of bounds
# Skipping user_id 18932 as it is out of bounds
# Skipping user_id 17822 as it is out of bounds
# Skipping user_id 7693 as it is out of bounds
# Skipping user_id 15115 as it is out of bounds
# Skipping user_id 10265 as it is out of bounds
# Skipping user_id 17760 as it is out of bounds
# Skipping user_id 20582 as it is out of bounds
# Skipping user_id 24149 as it is out of bounds
# Skipping user_id 23988 as it is out of bounds
# Skipping user_id 7011 as it is out of bounds
# Skipping user_id 27360 as it is out of bounds
# Skipping user_id 10247 as it is out of bounds
# Skipping user_id 9049 as it is out of bounds
# Skipping user_id 26118 as it is out of bounds
# Skipping user_id 16618 as it is out of bounds
# Skipping user_id 23640 as it is out of bounds
# Skipping user_id 25976 as it is out of bounds
# Skipping user_id 24855 as it is out of bounds
# Skipping user_id 14457 as it is out of bounds
# Skipping user_id 10969 as it is out of bounds
# Skipping user_id 19686 as it is out of bounds
# Skipping user_id 12853 as it is out of bounds
# Skipping user_id 23478 as it is out of bounds
# Skipping user_id 11238 as it is out of bounds
# Skipping user_id 7973 as it is out of bounds
# Skipping user_id 26338 as it is out of bounds
# Skipping user_id 9586 as it is out of bounds
# Skipping user_id 27144 as it is out of bounds
# Skipping user_id 13673 as it is out of bounds
# Skipping user_id 11668 as it is out of bounds
# Skipping user_id 7224 as it is out of bounds
# Skipping user_id 18912 as it is out of bounds
# Skipping user_id 9610 as it is out of bounds
# Skipping user_id 7977 as it is out of bounds
# Skipping user_id 18668 as it is out of bounds
# Skipping user_id 25337 as it is out of bounds
# Skipping user_id 13632 as it is out of bounds
# Skipping user_id 6827 as it is out of bounds
# Skipping user_id 19970 as it is out of bounds
# Skipping user_id 10874 as it is out of bounds
# Skipping user_id 26211 as it is out of bounds
# Skipping user_id 18916 as it is out of bounds
# Skipping user_id 13047 as it is out of bounds
# Skipping user_id 6826 as it is out of bounds
# Skipping user_id 21957 as it is out of bounds
# Skipping user_id 26885 as it is out of bounds
# Skipping user_id 28924 as it is out of bounds
# Skipping user_id 23232 as it is out of bounds
# Skipping user_id 15567 as it is out of bounds
# Skipping user_id 18276 as it is out of bounds
# Skipping user_id 21156 as it is out of bounds
# Skipping user_id 13955 as it is out of bounds
# Skipping user_id 25225 as it is out of bounds
# Skipping user_id 12745 as it is out of bounds
# Skipping user_id 13167 as it is out of bounds
# Skipping user_id 16712 as it is out of bounds
# Skipping user_id 19169 as it is out of bounds
# Skipping user_id 15556 as it is out of bounds
# Skipping user_id 21506 as it is out of bounds
# Skipping user_id 26120 as it is out of bounds
# Skipping user_id 12705 as it is out of bounds
# Skipping user_id 28358 as it is out of bounds
# Skipping user_id 19984 as it is out of bounds
# Skipping user_id 17797 as it is out of bounds
# Skipping user_id 9498 as it is out of bounds
# Skipping user_id 24631 as it is out of bounds
# Skipping user_id 7061 as it is out of bounds
# Skipping user_id 13208 as it is out of bounds
# Skipping user_id 27307 as it is out of bounds
# Skipping user_id 26359 as it is out of bounds
# Skipping user_id 13502 as it is out of bounds
# Skipping user_id 28554 as it is out of bounds
# Skipping user_id 14383 as it is out of bounds
# Skipping user_id 10787 as it is out of bounds
# Skipping user_id 25393 as it is out of bounds
# Skipping user_id 22583 as it is out of bounds
# Skipping user_id 14167 as it is out of bounds
# Skipping user_id 21647 as it is out of bounds
# Skipping user_id 14129 as it is out of bounds
# Skipping user_id 10478 as it is out of bounds
# Skipping user_id 11279 as it is out of bounds
# Skipping user_id 12769 as it is out of bounds
# Skipping user_id 10049 as it is out of bounds
# Skipping user_id 26764 as it is out of bounds
# Skipping user_id 12335 as it is out of bounds
# Skipping user_id 10392 as it is out of bounds
# Skipping user_id 16801 as it is out of bounds
# Skipping user_id 13332 as it is out of bounds
# Skipping user_id 22124 as it is out of bounds
# Skipping user_id 12464 as it is out of bounds
# Skipping user_id 9635 as it is out of bounds
# Skipping user_id 7060 as it is out of bounds
# Skipping user_id 16079 as it is out of bounds
# Skipping user_id 22099 as it is out of bounds
# Skipping user_id 8359 as it is out of bounds
# Skipping user_id 11273 as it is out of bounds
# Skipping user_id 25948 as it is out of bounds
# Skipping user_id 15014 as it is out of bounds
# Skipping user_id 23432 as it is out of bounds
# Skipping user_id 26761 as it is out of bounds
# Skipping user_id 24555 as it is out of bounds
# Skipping user_id 23077 as it is out of bounds
# Skipping user_id 28304 as it is out of bounds
# Skipping user_id 14928 as it is out of bounds
# Skipping user_id 21857 as it is out of bounds
# Skipping user_id 20952 as it is out of bounds
# Skipping user_id 8895 as it is out of bounds
# Skipping user_id 20232 as it is out of bounds
# Skipping user_id 21671 as it is out of bounds
# Skipping user_id 21089 as it is out of bounds
# Skipping user_id 8606 as it is out of bounds
# Skipping user_id 17699 as it is out of bounds
# Skipping user_id 25142 as it is out of bounds
# Skipping user_id 27860 as it is out of bounds
# Skipping user_id 14967 as it is out of bounds
# Skipping user_id 24173 as it is out of bounds
# Skipping user_id 27359 as it is out of bounds
# Skipping user_id 23848 as it is out of bounds
# Skipping user_id 28032 as it is out of bounds
# Skipping user_id 11985 as it is out of bounds
# Skipping user_id 20992 as it is out of bounds
# Skipping user_id 27087 as it is out of bounds
# Skipping user_id 9811 as it is out of bounds
# Skipping user_id 26386 as it is out of bounds
# Skipping user_id 27680 as it is out of bounds
# Skipping user_id 25664 as it is out of bounds
# Skipping user_id 12950 as it is out of bounds
# Skipping user_id 18467 as it is out of bounds
# Skipping user_id 7318 as it is out of bounds
# Skipping user_id 9653 as it is out of bounds
# Skipping user_id 12392 as it is out of bounds
# Skipping user_id 22312 as it is out of bounds
# Skipping user_id 13539 as it is out of bounds
# Skipping user_id 17874 as it is out of bounds
# Skipping user_id 22332 as it is out of bounds
# Skipping user_id 21260 as it is out of bounds
# Skipping user_id 8944 as it is out of bounds
# Skipping user_id 12253 as it is out of bounds
# Skipping user_id 12628 as it is out of bounds
# Skipping user_id 24591 as it is out of bounds
# Skipping user_id 23680 as it is out of bounds
# Skipping user_id 14151 as it is out of bounds
# Skipping user_id 13038 as it is out of bounds
# Skipping user_id 16719 as it is out of bounds
# Skipping user_id 27052 as it is out of bounds
# Skipping user_id 8650 as it is out of bounds
# Skipping user_id 26725 as it is out of bounds
# Skipping user_id 27239 as it is out of bounds
# Skipping user_id 26208 as it is out of bounds
# Skipping user_id 9421 as it is out of bounds
# Skipping user_id 18477 as it is out of bounds
# Skipping user_id 12015 as it is out of bounds
# Skipping user_id 20888 as it is out of bounds
# Skipping user_id 23994 as it is out of bounds
# Skipping user_id 8735 as it is out of bounds
# Skipping user_id 11786 as it is out of bounds
# Skipping user_id 11055 as it is out of bounds
# Skipping user_id 20364 as it is out of bounds
# Skipping user_id 10746 as it is out of bounds
# Skipping user_id 13458 as it is out of bounds
# Skipping user_id 12606 as it is out of bounds
# Skipping user_id 24245 as it is out of bounds
# Skipping user_id 18613 as it is out of bounds
# Skipping user_id 19791 as it is out of bounds
# Skipping user_id 28011 as it is out of bounds
# Skipping user_id 9790 as it is out of bounds
# Skipping user_id 28479 as it is out of bounds
# Skipping user_id 16183 as it is out of bounds
# Skipping user_id 22617 as it is out of bounds
# Skipping user_id 28242 as it is out of bounds
# Skipping user_id 25983 as it is out of bounds
# Skipping user_id 11874 as it is out of bounds
# Skipping user_id 27912 as it is out of bounds
# Skipping user_id 9701 as it is out of bounds
# Skipping user_id 7127 as it is out of bounds
# Skipping user_id 26245 as it is out of bounds
# Skipping user_id 9371 as it is out of bounds
# Skipping user_id 19865 as it is out of bounds
# Skipping user_id 19861 as it is out of bounds
# Skipping user_id 7766 as it is out of bounds
# Skipping user_id 20858 as it is out of bounds
# Skipping user_id 24709 as it is out of bounds
# Skipping user_id 14276 as it is out of bounds
# Skipping user_id 12688 as it is out of bounds
# Skipping user_id 15991 as it is out of bounds
# Skipping user_id 27593 as it is out of bounds
# Skipping user_id 24250 as it is out of bounds
# Skipping user_id 11706 as it is out of bounds
# Skipping user_id 21799 as it is out of bounds
# Skipping user_id 8421 as it is out of bounds
# Skipping user_id 13000 as it is out of bounds
# Skipping user_id 20300 as it is out of bounds
# Skipping user_id 20100 as it is out of bounds
# Skipping user_id 25757 as it is out of bounds
# Skipping user_id 14376 as it is out of bounds
# Skipping user_id 9514 as it is out of bounds
# Skipping user_id 28299 as it is out of bounds
# Skipping user_id 17879 as it is out of bounds
# Skipping user_id 17756 as it is out of bounds
# Skipping user_id 17202 as it is out of bounds
# Skipping user_id 17166 as it is out of bounds
# Skipping user_id 9644 as it is out of bounds
# Skipping user_id 14181 as it is out of bounds
# Skipping user_id 8339 as it is out of bounds
# Skipping user_id 21791 as it is out of bounds
# Skipping user_id 7741 as it is out of bounds
# Skipping user_id 8137 as it is out of bounds
# Skipping user_id 10803 as it is out of bounds
# Skipping user_id 18362 as it is out of bounds
# Skipping user_id 12563 as it is out of bounds
# Skipping user_id 18935 as it is out of bounds
# Skipping user_id 23298 as it is out of bounds
# Skipping user_id 28672 as it is out of bounds
# Skipping user_id 9794 as it is out of bounds
# Skipping user_id 20947 as it is out of bounds
# Skipping user_id 11289 as it is out of bounds
# Skipping user_id 10354 as it is out of bounds
# Skipping user_id 28664 as it is out of bounds
# Skipping user_id 20849 as it is out of bounds
# Skipping user_id 17793 as it is out of bounds
# Skipping user_id 8738 as it is out of bounds
# Skipping user_id 17782 as it is out of bounds
# Skipping user_id 18595 as it is out of bounds
# Skipping user_id 16046 as it is out of bounds
# Skipping user_id 11583 as it is out of bounds
# Skipping user_id 14788 as it is out of bounds
# Skipping user_id 16366 as it is out of bounds
# Skipping user_id 25201 as it is out of bounds
# Skipping user_id 8564 as it is out of bounds
# Skipping user_id 9227 as it is out of bounds
# Skipping user_id 18425 as it is out of bounds
# Skipping user_id 8816 as it is out of bounds
# Skipping user_id 12151 as it is out of bounds
# Skipping user_id 23255 as it is out of bounds
# Skipping user_id 26886 as it is out of bounds
# Skipping user_id 19255 as it is out of bounds
# Skipping user_id 23292 as it is out of bounds
# Skipping user_id 12572 as it is out of bounds
# Skipping user_id 10786 as it is out of bounds
# Skipping user_id 23643 as it is out of bounds
# Skipping user_id 28801 as it is out of bounds
# Skipping user_id 7767 as it is out of bounds
# Skipping user_id 28214 as it is out of bounds
# Skipping user_id 11310 as it is out of bounds
# Skipping user_id 18496 as it is out of bounds
# Skipping user_id 26906 as it is out of bounds
# Skipping user_id 18838 as it is out of bounds
# Skipping user_id 27958 as it is out of bounds
# Skipping user_id 10157 as it is out of bounds
# Skipping user_id 25023 as it is out of bounds
# Skipping user_id 23209 as it is out of bounds
# Skipping user_id 22261 as it is out of bounds
# Skipping user_id 27152 as it is out of bounds
# Skipping user_id 12256 as it is out of bounds
# Skipping user_id 22825 as it is out of bounds
# Skipping user_id 20836 as it is out of bounds
# Skipping user_id 19727 as it is out of bounds
# Skipping user_id 7706 as it is out of bounds
# Skipping user_id 7015 as it is out of bounds
# Skipping user_id 15204 as it is out of bounds
# Skipping user_id 14352 as it is out of bounds
# Skipping user_id 26783 as it is out of bounds
# Skipping user_id 17524 as it is out of bounds
# Skipping user_id 7623 as it is out of bounds
# Skipping user_id 19718 as it is out of bounds
# Skipping user_id 8513 as it is out of bounds
# Skipping user_id 13503 as it is out of bounds
# Skipping user_id 17280 as it is out of bounds
# Skipping user_id 7564 as it is out of bounds
# Skipping user_id 16234 as it is out of bounds
# Skipping user_id 27858 as it is out of bounds
# Skipping user_id 15499 as it is out of bounds
# Skipping user_id 21361 as it is out of bounds
# Skipping user_id 14978 as it is out of bounds
# Skipping user_id 23872 as it is out of bounds
# Skipping user_id 25446 as it is out of bounds
# Skipping user_id 28259 as it is out of bounds
# Skipping user_id 28347 as it is out of bounds
# Skipping user_id 8365 as it is out of bounds
# Skipping user_id 8115 as it is out of bounds
# Skipping user_id 22321 as it is out of bounds
# Skipping user_id 22630 as it is out of bounds
# Skipping user_id 20823 as it is out of bounds
# Skipping user_id 23406 as it is out of bounds
# Skipping user_id 20351 as it is out of bounds
# Skipping user_id 26625 as it is out of bounds
# Skipping user_id 7424 as it is out of bounds
# Skipping user_id 19230 as it is out of bounds
# Skipping user_id 12764 as it is out of bounds
# Skipping user_id 10627 as it is out of bounds
# Skipping user_id 28727 as it is out of bounds
# Skipping user_id 16870 as it is out of bounds
# Skipping user_id 10056 as it is out of bounds
# Skipping user_id 11328 as it is out of bounds
# Skipping user_id 9818 as it is out of bounds
# Skipping user_id 27264 as it is out of bounds
# Skipping user_id 12521 as it is out of bounds
# Skipping user_id 15539 as it is out of bounds
# Skipping user_id 18224 as it is out of bounds
# Skipping user_id 11570 as it is out of bounds
# Skipping user_id 10050 as it is out of bounds
# Skipping user_id 18865 as it is out of bounds
# Skipping user_id 9101 as it is out of bounds
# Skipping user_id 22762 as it is out of bounds
# Skipping user_id 17256 as it is out of bounds
# Skipping user_id 27574 as it is out of bounds
# Skipping user_id 7293 as it is out of bounds
# Skipping user_id 8473 as it is out of bounds
# Skipping user_id 21512 as it is out of bounds
# Skipping user_id 17352 as it is out of bounds
# Skipping user_id 24237 as it is out of bounds
# Skipping user_id 23623 as it is out of bounds
# Skipping user_id 23888 as it is out of bounds
# Skipping user_id 21434 as it is out of bounds
# Skipping user_id 14215 as it is out of bounds
# Skipping user_id 27901 as it is out of bounds
# Skipping user_id 17849 as it is out of bounds
# Skipping user_id 12173 as it is out of bounds
# Skipping user_id 18180 as it is out of bounds
# Skipping user_id 16835 as it is out of bounds
# Skipping user_id 23814 as it is out of bounds
# Skipping user_id 26620 as it is out of bounds
# Skipping user_id 9222 as it is out of bounds
# Skipping user_id 11234 as it is out of bounds
# Skipping user_id 13511 as it is out of bounds
# Skipping user_id 19323 as it is out of bounds
# Skipping user_id 27995 as it is out of bounds
# Skipping user_id 10278 as it is out of bounds
# Skipping user_id 11785 as it is out of bounds
# Skipping user_id 9119 as it is out of bounds
# Skipping user_id 13815 as it is out of bounds
# Skipping user_id 27294 as it is out of bounds
# Skipping user_id 23128 as it is out of bounds
# Skipping user_id 14077 as it is out of bounds
# Skipping user_id 16846 as it is out of bounds
# Skipping user_id 22808 as it is out of bounds
# Skipping user_id 12344 as it is out of bounds
# Skipping user_id 15447 as it is out of bounds
# Skipping user_id 10198 as it is out of bounds
# Skipping user_id 26552 as it is out of bounds
# Skipping user_id 22034 as it is out of bounds
# Skipping user_id 25909 as it is out of bounds
# Skipping user_id 21699 as it is out of bounds
# Skipping user_id 15195 as it is out of bounds
# Skipping user_id 16608 as it is out of bounds
# Skipping user_id 15543 as it is out of bounds
# Skipping user_id 9389 as it is out of bounds
# Skipping user_id 22641 as it is out of bounds
# Skipping user_id 21255 as it is out of bounds
# Skipping user_id 17420 as it is out of bounds
# Skipping user_id 18422 as it is out of bounds
# Skipping user_id 25066 as it is out of bounds
# Skipping user_id 18509 as it is out of bounds
# Skipping user_id 16224 as it is out of bounds
# Skipping user_id 22064 as it is out of bounds
# Skipping user_id 21242 as it is out of bounds
# Skipping user_id 18210 as it is out of bounds
# Skipping user_id 7143 as it is out of bounds
# Skipping user_id 13203 as it is out of bounds
# Skipping user_id 20381 as it is out of bounds
# Skipping user_id 20734 as it is out of bounds
# Skipping user_id 25055 as it is out of bounds
# Skipping user_id 10654 as it is out of bounds
# Skipping user_id 14940 as it is out of bounds
# Skipping user_id 23396 as it is out of bounds
# Skipping user_id 25371 as it is out of bounds
# Skipping user_id 7911 as it is out of bounds
# Skipping user_id 8538 as it is out of bounds
# Skipping user_id 28961 as it is out of bounds
# Skipping user_id 27763 as it is out of bounds
# Skipping user_id 27488 as it is out of bounds
# Skipping user_id 7556 as it is out of bounds
# Skipping user_id 17098 as it is out of bounds
# Skipping user_id 9534 as it is out of bounds
# Skipping user_id 13305 as it is out of bounds
# Skipping user_id 23398 as it is out of bounds
# Skipping user_id 12452 as it is out of bounds
# Skipping user_id 8405 as it is out of bounds
# Skipping user_id 26749 as it is out of bounds
# Skipping user_id 8453 as it is out of bounds
# Skipping user_id 7008 as it is out of bounds
# Skipping user_id 18839 as it is out of bounds
# Skipping user_id 16098 as it is out of bounds
# Skipping user_id 24202 as it is out of bounds
# Skipping user_id 10559 as it is out of bounds
# Skipping user_id 26938 as it is out of bounds
# Skipping user_id 11887 as it is out of bounds
# Skipping user_id 20663 as it is out of bounds
# Skipping user_id 21637 as it is out of bounds
# Skipping user_id 16474 as it is out of bounds
# Skipping user_id 28046 as it is out of bounds
# Skipping user_id 10999 as it is out of bounds
# Skipping user_id 20414 as it is out of bounds
# Skipping user_id 25260 as it is out of bounds
# Skipping user_id 13876 as it is out of bounds
# Skipping user_id 22812 as it is out of bounds
# Skipping user_id 18678 as it is out of bounds
# Skipping user_id 11836 as it is out of bounds
# Skipping user_id 7188 as it is out of bounds
# Skipping user_id 17159 as it is out of bounds
# Skipping user_id 24974 as it is out of bounds
# Skipping user_id 7361 as it is out of bounds
# Skipping user_id 11868 as it is out of bounds
# Skipping user_id 11979 as it is out of bounds
# Skipping user_id 25698 as it is out of bounds
# Skipping user_id 22230 as it is out of bounds
# Skipping user_id 17485 as it is out of bounds
# Skipping user_id 27278 as it is out of bounds
# Skipping user_id 25837 as it is out of bounds
# Skipping user_id 20716 as it is out of bounds
# Skipping user_id 8625 as it is out of bounds
# Skipping user_id 28050 as it is out of bounds
# Skipping user_id 12025 as it is out of bounds
# Skipping user_id 7354 as it is out of bounds
# Skipping user_id 8605 as it is out of bounds
# Skipping user_id 26606 as it is out of bounds
# Skipping user_id 9553 as it is out of bounds
# Skipping user_id 26039 as it is out of bounds
# Skipping user_id 8885 as it is out of bounds
# Skipping user_id 18697 as it is out of bounds
# Skipping user_id 25492 as it is out of bounds
# Skipping user_id 9117 as it is out of bounds
# Skipping user_id 17120 as it is out of bounds
# Skipping user_id 18846 as it is out of bounds
# Skipping user_id 23616 as it is out of bounds
# Skipping user_id 18964 as it is out of bounds
# Skipping user_id 24346 as it is out of bounds
# Skipping user_id 11063 as it is out of bounds
# Skipping user_id 7098 as it is out of bounds
# Skipping user_id 13104 as it is out of bounds
# Skipping user_id 12999 as it is out of bounds
# Skipping user_id 21500 as it is out of bounds
# Skipping user_id 16396 as it is out of bounds
# Skipping user_id 14245 as it is out of bounds
# Skipping user_id 17079 as it is out of bounds
# Skipping user_id 10132 as it is out of bounds
# Skipping user_id 26867 as it is out of bounds
# Skipping user_id 23799 as it is out of bounds
# Skipping user_id 18656 as it is out of bounds
# Skipping user_id 21026 as it is out of bounds
# Skipping user_id 9742 as it is out of bounds
# Skipping user_id 20994 as it is out of bounds
# Skipping user_id 17902 as it is out of bounds
# Skipping user_id 16493 as it is out of bounds
# Skipping user_id 8874 as it is out of bounds
# Skipping user_id 22949 as it is out of bounds
# Skipping user_id 15816 as it is out of bounds
# Skipping user_id 22298 as it is out of bounds
# Skipping user_id 7520 as it is out of bounds
# Skipping user_id 7398 as it is out of bounds
# Skipping user_id 13199 as it is out of bounds
# Skipping user_id 25084 as it is out of bounds
# Skipping user_id 13547 as it is out of bounds
# Skipping user_id 13211 as it is out of bounds
# Skipping user_id 15319 as it is out of bounds
# Skipping user_id 15107 as it is out of bounds
# Skipping user_id 7251 as it is out of bounds
# Skipping user_id 23902 as it is out of bounds
# Skipping user_id 18046 as it is out of bounds
# Skipping user_id 23357 as it is out of bounds
# Skipping user_id 20936 as it is out of bounds
# Skipping user_id 22822 as it is out of bounds
# Skipping user_id 12294 as it is out of bounds
# Skipping user_id 17036 as it is out of bounds
# Skipping user_id 20840 as it is out of bounds
# Skipping user_id 22611 as it is out of bounds
# Skipping user_id 10671 as it is out of bounds
# Skipping user_id 8663 as it is out of bounds
# Skipping user_id 13667 as it is out of bounds
# Skipping user_id 15664 as it is out of bounds
# Skipping user_id 15508 as it is out of bounds
# Skipping user_id 12847 as it is out of bounds
# Skipping user_id 27636 as it is out of bounds
# Skipping user_id 23740 as it is out of bounds
# Skipping user_id 15866 as it is out of bounds
# Skipping user_id 19876 as it is out of bounds
# Skipping user_id 7436 as it is out of bounds
# Skipping user_id 28600 as it is out of bounds
# Skipping user_id 9273 as it is out of bounds
# Skipping user_id 21981 as it is out of bounds
# Skipping user_id 22519 as it is out of bounds
# Skipping user_id 23612 as it is out of bounds
# Skipping user_id 19985 as it is out of bounds
# Skipping user_id 22657 as it is out of bounds
# Skipping user_id 8954 as it is out of bounds
# Skipping user_id 16758 as it is out of bounds
# Skipping user_id 18446 as it is out of bounds
# Skipping user_id 22819 as it is out of bounds
# Skipping user_id 17854 as it is out of bounds
# Skipping user_id 22402 as it is out of bounds
# Skipping user_id 17133 as it is out of bounds
# Skipping user_id 17144 as it is out of bounds
# Skipping user_id 8739 as it is out of bounds
# Skipping user_id 9969 as it is out of bounds
# Skipping user_id 7596 as it is out of bounds
# Skipping user_id 16050 as it is out of bounds
# Skipping user_id 19395 as it is out of bounds
# Skipping user_id 13917 as it is out of bounds
# Skipping user_id 23726 as it is out of bounds
# Skipping user_id 25738 as it is out of bounds
# Skipping user_id 25688 as it is out of bounds
# Skipping user_id 27069 as it is out of bounds
# Skipping user_id 16715 as it is out of bounds
# Skipping user_id 9047 as it is out of bounds
# Skipping user_id 15500 as it is out of bounds
# Skipping user_id 25493 as it is out of bounds
# Skipping user_id 24986 as it is out of bounds
# Skipping user_id 10462 as it is out of bounds
# Skipping user_id 10649 as it is out of bounds
# Skipping user_id 14871 as it is out of bounds
# Skipping user_id 8654 as it is out of bounds
# Skipping user_id 20728 as it is out of bounds
# Skipping user_id 22063 as it is out of bounds
# Skipping user_id 22102 as it is out of bounds
# Skipping user_id 23147 as it is out of bounds
# Skipping user_id 21064 as it is out of bounds
# Skipping user_id 23064 as it is out of bounds
# Skipping user_id 13885 as it is out of bounds
# Skipping user_id 10516 as it is out of bounds
# Skipping user_id 10777 as it is out of bounds
# Skipping user_id 18217 as it is out of bounds
# Skipping user_id 24377 as it is out of bounds
# Skipping user_id 10897 as it is out of bounds
# Skipping user_id 22007 as it is out of bounds
# Skipping user_id 13296 as it is out of bounds
# Skipping user_id 27786 as it is out of bounds
# Skipping user_id 11488 as it is out of bounds
# Skipping user_id 25379 as it is out of bounds
# Skipping user_id 20205 as it is out of bounds
# Skipping user_id 21185 as it is out of bounds
# Skipping user_id 18659 as it is out of bounds
# Skipping user_id 18751 as it is out of bounds
# Skipping user_id 19449 as it is out of bounds
# Skipping user_id 17985 as it is out of bounds
# Skipping user_id 13075 as it is out of bounds
# Skipping user_id 15853 as it is out of bounds
# Skipping user_id 23925 as it is out of bounds
# Skipping user_id 7757 as it is out of bounds
# Skipping user_id 27562 as it is out of bounds
# Skipping user_id 15574 as it is out of bounds
# Skipping user_id 10220 as it is out of bounds
# Skipping user_id 17861 as it is out of bounds
# Skipping user_id 21416 as it is out of bounds
# Skipping user_id 26817 as it is out of bounds
# Skipping user_id 18762 as it is out of bounds
# Skipping user_id 13858 as it is out of bounds
# Skipping user_id 24971 as it is out of bounds
# Skipping user_id 15222 as it is out of bounds
# Skipping user_id 25647 as it is out of bounds
# Skipping user_id 12399 as it is out of bounds
# Skipping user_id 8198 as it is out of bounds
# Skipping user_id 14633 as it is out of bounds
# Skipping user_id 21678 as it is out of bounds
# Skipping user_id 23184 as it is out of bounds
# Skipping user_id 14599 as it is out of bounds
# Skipping user_id 22733 as it is out of bounds
# Skipping user_id 13429 as it is out of bounds
# Skipping user_id 11479 as it is out of bounds
# Skipping user_id 23693 as it is out of bounds
# Skipping user_id 11506 as it is out of bounds
# Skipping user_id 28822 as it is out of bounds
# Skipping user_id 11627 as it is out of bounds
# Skipping user_id 9292 as it is out of bounds
# Skipping user_id 9459 as it is out of bounds
# Skipping user_id 18803 as it is out of bounds
# Skipping user_id 23603 as it is out of bounds
# Skipping user_id 25731 as it is out of bounds
# Skipping user_id 9271 as it is out of bounds
# Skipping user_id 24272 as it is out of bounds
# Skipping user_id 7728 as it is out of bounds
# Skipping user_id 26328 as it is out of bounds
# Skipping user_id 13538 as it is out of bounds
# Skipping user_id 27368 as it is out of bounds
# Skipping user_id 27021 as it is out of bounds
# Skipping user_id 20485 as it is out of bounds
# Skipping user_id 9333 as it is out of bounds
# Skipping user_id 20904 as it is out of bounds
# Skipping user_id 11064 as it is out of bounds
# Skipping user_id 26205 as it is out of bounds
# Skipping user_id 17757 as it is out of bounds
# Skipping user_id 28753 as it is out of bounds
# Skipping user_id 10525 as it is out of bounds
# Skipping user_id 24523 as it is out of bounds
# Skipping user_id 21218 as it is out of bounds
# Skipping user_id 20752 as it is out of bounds
# Skipping user_id 15513 as it is out of bounds
# Skipping user_id 20897 as it is out of bounds
# Skipping user_id 22880 as it is out of bounds
# Skipping user_id 17644 as it is out of bounds
# Skipping user_id 19151 as it is out of bounds
# Skipping user_id 23212 as it is out of bounds
# Skipping user_id 11133 as it is out of bounds
# Skipping user_id 8253 as it is out of bounds
# Skipping user_id 16772 as it is out of bounds
# Skipping user_id 12136 as it is out of bounds
# Skipping user_id 20865 as it is out of bounds
# Skipping user_id 8021 as it is out of bounds
# Skipping user_id 21012 as it is out of bounds
# Skipping user_id 8768 as it is out of bounds
# Skipping user_id 16934 as it is out of bounds
# Skipping user_id 13517 as it is out of bounds
# Skipping user_id 27776 as it is out of bounds
# Skipping user_id 22838 as it is out of bounds
# Skipping user_id 25184 as it is out of bounds
# Skipping user_id 27646 as it is out of bounds
# Skipping user_id 8526 as it is out of bounds
# Skipping user_id 9340 as it is out of bounds
# Skipping user_id 9248 as it is out of bounds
# Skipping user_id 15033 as it is out of bounds
# Skipping user_id 18456 as it is out of bounds
# Skipping user_id 25795 as it is out of bounds
# Skipping user_id 12147 as it is out of bounds
# Skipping user_id 26602 as it is out of bounds
# Skipping user_id 16135 as it is out of bounds
# Skipping user_id 27354 as it is out of bounds
# Skipping user_id 13574 as it is out of bounds
# Skipping user_id 12809 as it is out of bounds
# Skipping user_id 9654 as it is out of bounds
# Skipping user_id 20065 as it is out of bounds
# Skipping user_id 7647 as it is out of bounds
# Skipping user_id 27949 as it is out of bounds
# Skipping user_id 18645 as it is out of bounds
# Skipping user_id 26876 as it is out of bounds
# Skipping user_id 16892 as it is out of bounds
# Skipping user_id 10156 as it is out of bounds
# Skipping user_id 13857 as it is out of bounds
# Skipping user_id 6821 as it is out of bounds
# Skipping user_id 8612 as it is out of bounds
# Skipping user_id 16596 as it is out of bounds
# Skipping user_id 20388 as it is out of bounds
# Skipping user_id 26486 as it is out of bounds
# Skipping user_id 22183 as it is out of bounds
# Skipping user_id 7885 as it is out of bounds
# Skipping user_id 23361 as it is out of bounds
# Skipping user_id 20969 as it is out of bounds
# Skipping user_id 28704 as it is out of bounds
# Skipping user_id 24768 as it is out of bounds
# Skipping user_id 24034 as it is out of bounds
# Skipping user_id 16368 as it is out of bounds
# Skipping user_id 7726 as it is out of bounds
# Skipping user_id 13820 as it is out of bounds
# Skipping user_id 28022 as it is out of bounds
# Skipping user_id 22376 as it is out of bounds
# Skipping user_id 8759 as it is out of bounds
# Skipping user_id 16651 as it is out of bounds
# Skipping user_id 7101 as it is out of bounds
# Skipping user_id 17676 as it is out of bounds
# Skipping user_id 23046 as it is out of bounds
# Skipping user_id 15167 as it is out of bounds
# Skipping user_id 19069 as it is out of bounds
# Skipping user_id 21912 as it is out of bounds
# Skipping user_id 7223 as it is out of bounds
# Skipping user_id 24025 as it is out of bounds
# Skipping user_id 18500 as it is out of bounds
# Skipping user_id 8970 as it is out of bounds
# Skipping user_id 11697 as it is out of bounds
# Skipping user_id 9758 as it is out of bounds
# Skipping user_id 17581 as it is out of bounds
# Skipping user_id 20586 as it is out of bounds
# Skipping user_id 10438 as it is out of bounds
# Skipping user_id 16248 as it is out of bounds
# Skipping user_id 12525 as it is out of bounds
# Skipping user_id 9407 as it is out of bounds
# ...
# Skipping user_id 7573 as it is out of bounds
# Skipping user_id 9706 as it is out of bounds
# Skipping user_id 12181 as it is out of bounds
# Skipping user_id 24745 as it is out of bounds
# Skipping user_id 10047 as it is out of bounds
# Skipping user_id 7088 as it is out of bounds
# Skipping user_id 18811 as it is out of bounds
# Skipping user_id 24518 as it is out of bounds
# Skipping user_id 13852 as it is out of bounds
# Skipping user_id 9808 as it is out of bounds
# Skipping user_id 14953 as it is out of bounds
# Skipping user_id 9549 as it is out of bounds
# Skipping user_id 12598 as it is out of bounds
# Skipping user_id 21558 as it is out of bounds
# Skipping user_id 17638 as it is out of bounds
# Skipping user_id 14084 as it is out of bounds
# Skipping user_id 15182 as it is out of bounds
# Skipping user_id 24419 as it is out of bounds
# Skipping user_id 9585 as it is out of bounds
# Skipping user_id 22522 as it is out of bounds
# Skipping user_id 16233 as it is out of bounds
# Skipping user_id 15537 as it is out of bounds
# Skipping user_id 17811 as it is out of bounds
# Skipping user_id 15341 as it is out of bounds
# Skipping user_id 28515 as it is out of bounds
# Skipping user_id 22268 as it is out of bounds
# Skipping user_id 16439 as it is out of bounds
# Skipping user_id 18002 as it is out of bounds
# Skipping user_id 15152 as it is out of bounds
# Skipping user_id 14897 as it is out of bounds
# Skipping user_id 17339 as it is out of bounds
# Skipping user_id 8730 as it is out of bounds
# Skipping user_id 26703 as it is out of bounds
# Skipping user_id 26238 as it is out of bounds
# Skipping user_id 18235 as it is out of bounds
# Skipping user_id 14717 as it is out of bounds
# Skipping user_id 8764 as it is out of bounds
# Skipping user_id 28775 as it is out of bounds
# Skipping user_id 10244 as it is out of bounds
# Skipping user_id 11878 as it is out of bounds
# Skipping user_id 17820 as it is out of bounds
# Skipping user_id 26866 as it is out of bounds
# Skipping user_id 22744 as it is out of bounds
# Skipping user_id 6936 as it is out of bounds
# Skipping user_id 17889 as it is out of bounds
# Skipping user_id 20114 as it is out of bounds
# Skipping user_id 17552 as it is out of bounds
# Skipping user_id 23578 as it is out of bounds
# Skipping user_id 14384 as it is out of bounds
# Skipping user_id 20989 as it is out of bounds
# Skipping user_id 12676 as it is out of bounds
# Skipping user_id 27301 as it is out of bounds
# Skipping user_id 28149 as it is out of bounds
# Skipping user_id 19188 as it is out of bounds
# Skipping user_id 6880 as it is out of bounds
# Skipping user_id 12388 as it is out of bounds
# Skipping user_id 21612 as it is out of bounds
# Skipping user_id 14380 as it is out of bounds
# Skipping user_id 17075 as it is out of bounds
# Skipping user_id 13627 as it is out of bounds
# Skipping user_id 7020 as it is out of bounds
# Skipping user_id 11890 as it is out of bounds
# Skipping user_id 25149 as it is out of bounds
# Skipping user_id 26755 as it is out of bounds
# Skipping user_id 22255 as it is out of bounds
# Skipping user_id 21962 as it is out of bounds
# Skipping user_id 7893 as it is out of bounds
# Skipping user_id 27219 as it is out of bounds
# Skipping user_id 12790 as it is out of bounds
# Skipping user_id 11052 as it is out of bounds
# Skipping user_id 25293 as it is out of bounds
# Skipping user_id 20785 as it is out of bounds
# Skipping user_id 15630 as it is out of bounds
# Skipping user_id 9289 as it is out of bounds
# Skipping user_id 13269 as it is out of bounds
# Skipping user_id 13137 as it is out of bounds
# Skipping user_id 28745 as it is out of bounds
# Skipping user_id 15431 as it is out of bounds
# Skipping user_id 15876 as it is out of bounds
# Skipping user_id 11991 as it is out of bounds
# Skipping user_id 24769 as it is out of bounds
# Skipping user_id 22286 as it is out of bounds
# Skipping user_id 23338 as it is out of bounds
# Skipping user_id 27889 as it is out of bounds
# Skipping user_id 24783 as it is out of bounds
# Skipping user_id 23555 as it is out of bounds
# Skipping user_id 10092 as it is out of bounds
# Skipping user_id 16192 as it is out of bounds
# Skipping user_id 28273 as it is out of bounds
# Skipping user_id 13380 as it is out of bounds
# Skipping user_id 7595 as it is out of bounds
# Skipping user_id 14614 as it is out of bounds
# Skipping user_id 15519 as it is out of bounds
# Skipping user_id 17413 as it is out of bounds
# Skipping user_id 14839 as it is out of bounds
# Skipping user_id 7983 as it is out of bounds
# Skipping user_id 15419 as it is out of bounds
# Skipping user_id 16874 as it is out of bounds
# Skipping user_id 11835 as it is out of bounds
# Skipping user_id 19751 as it is out of bounds
# Skipping user_id 21847 as it is out of bounds
# Skipping user_id 28029 as it is out of bounds
# Skipping user_id 7112 as it is out of bounds
# Skipping user_id 18259 as it is out of bounds
# Skipping user_id 21037 as it is out of bounds
# Skipping user_id 12652 as it is out of bounds
# Skipping user_id 12817 as it is out of bounds
# Skipping user_id 18584 as it is out of bounds
# Skipping user_id 13313 as it is out of bounds
# Skipping user_id 26844 as it is out of bounds
# Skipping user_id 23156 as it is out of bounds
# Skipping user_id 19316 as it is out of bounds
# Skipping user_id 19703 as it is out of bounds
# Skipping user_id 17996 as it is out of bounds
# Skipping user_id 27309 as it is out of bounds
# Skipping user_id 14891 as it is out of bounds
# Skipping user_id 8055 as it is out of bounds
# Skipping user_id 23734 as it is out of bounds
# Skipping user_id 7102 as it is out of bounds
# Skipping user_id 25510 as it is out of bounds
# Skipping user_id 13068 as it is out of bounds
# Skipping user_id 26231 as it is out of bounds
# Skipping user_id 9802 as it is out of bounds
# Skipping user_id 26052 as it is out of bounds
# Skipping user_id 18294 as it is out of bounds
# Skipping user_id 20680 as it is out of bounds
# Skipping user_id 28044 as it is out of bounds
# Skipping user_id 19665 as it is out of bounds
# Skipping user_id 11416 as it is out of bounds
# Skipping user_id 16249 as it is out of bounds
# Skipping user_id 11455 as it is out of bounds
# Skipping user_id 24150 as it is out of bounds
# Skipping user_id 20954 as it is out of bounds
# Skipping user_id 23428 as it is out of bounds
# Skipping user_id 10792 as it is out of bounds
# Skipping user_id 15231 as it is out of bounds
# Skipping user_id 24499 as it is out of bounds
# Skipping user_id 14647 as it is out of bounds
# Skipping user_id 15494 as it is out of bounds
# Skipping user_id 23104 as it is out of bounds
# Skipping user_id 22883 as it is out of bounds
# Skipping user_id 18977 as it is out of bounds
# Skipping user_id 25073 as it is out of bounds
# Skipping user_id 15343 as it is out of bounds
# Skipping user_id 26181 as it is out of bounds
# Skipping user_id 28877 as it is out of bounds
# Skipping user_id 24739 as it is out of bounds
# Skipping user_id 24031 as it is out of bounds
# Skipping user_id 17934 as it is out of bounds
# Skipping user_id 26789 as it is out of bounds
# Skipping user_id 8416 as it is out of bounds
# Skipping user_id 7593 as it is out of bounds
# Skipping user_id 8595 as it is out of bounds
# Skipping user_id 25832 as it is out of bounds
# Skipping user_id 15453 as it is out of bounds
# Skipping user_id 15000 as it is out of bounds
# Skipping user_id 14830 as it is out of bounds
# Skipping user_id 18909 as it is out of bounds
# Skipping user_id 11107 as it is out of bounds
# Skipping user_id 24195 as it is out of bounds
# Skipping user_id 15048 as it is out of bounds
# Skipping user_id 27971 as it is out of bounds
# Skipping user_id 27872 as it is out of bounds
# Skipping user_id 9853 as it is out of bounds
# Skipping user_id 10371 as it is out of bounds
# Skipping user_id 19938 as it is out of bounds
# Skipping user_id 14112 as it is out of bounds
# Skipping user_id 23190 as it is out of bounds
# Skipping user_id 25179 as it is out of bounds
# Skipping user_id 7927 as it is out of bounds
# Skipping user_id 26276 as it is out of bounds
# Skipping user_id 23704 as it is out of bounds
# Skipping user_id 23038 as it is out of bounds
# Skipping user_id 14445 as it is out of bounds
# Skipping user_id 9424 as it is out of bounds
# Skipping user_id 22413 as it is out of bounds
# Skipping user_id 15495 as it is out of bounds
# Skipping user_id 15069 as it is out of bounds
# Skipping user_id 8219 as it is out of bounds
# Skipping user_id 11920 as it is out of bounds
# Skipping user_id 23916 as it is out of bounds
# Skipping user_id 11065 as it is out of bounds
# Skipping user_id 7567 as it is out of bounds
# Skipping user_id 22656 as it is out of bounds
# Skipping user_id 22324 as it is out of bounds
# Skipping user_id 18885 as it is out of bounds
# Skipping user_id 13108 as it is out of bounds
# Skipping user_id 13515 as it is out of bounds
# Skipping user_id 20426 as it is out of bounds
# Skipping user_id 14958 as it is out of bounds
# Skipping user_id 8861 as it is out of bounds
# Skipping user_id 9606 as it is out of bounds
# Skipping user_id 20813 as it is out of bounds
# Skipping user_id 7444 as it is out of bounds
# Skipping user_id 27658 as it is out of bounds
# Skipping user_id 22320 as it is out of bounds
# Skipping user_id 8560 as it is out of bounds
# Skipping user_id 27120 as it is out of bounds
# Skipping user_id 23430 as it is out of bounds
# Skipping user_id 17908 as it is out of bounds
# Skipping user_id 12371 as it is out of bounds
# Skipping user_id 19404 as it is out of bounds
# Skipping user_id 21757 as it is out of bounds
# Skipping user_id 26792 as it is out of bounds
# Skipping user_id 17673 as it is out of bounds
# Skipping user_id 19380 as it is out of bounds
# Skipping user_id 8713 as it is out of bounds
# Skipping user_id 12933 as it is out of bounds
# Skipping user_id 20000 as it is out of bounds
# Skipping user_id 8968 as it is out of bounds
# Skipping user_id 8864 as it is out of bounds
# Skipping user_id 13795 as it is out of bounds
# Skipping user_id 8011 as it is out of bounds
# Skipping user_id 22233 as it is out of bounds
# Skipping user_id 18709 as it is out of bounds
# Skipping user_id 12834 as it is out of bounds
# Skipping user_id 24845 as it is out of bounds
# Skipping user_id 10975 as it is out of bounds
# Skipping user_id 25620 as it is out of bounds
# Skipping user_id 9266 as it is out of bounds
# Skipping user_id 7486 as it is out of bounds
# Skipping user_id 20876 as it is out of bounds
# Skipping user_id 23970 as it is out of bounds
# Skipping user_id 10851 as it is out of bounds
# Skipping user_id 15102 as it is out of bounds
# Skipping user_id 26922 as it is out of bounds
# Skipping user_id 28275 as it is out of bounds
# Skipping user_id 18150 as it is out of bounds
# Skipping user_id 8214 as it is out of bounds
# Skipping user_id 8547 as it is out of bounds
# Skipping user_id 10876 as it is out of bounds
# Skipping user_id 18284 as it is out of bounds
# Skipping user_id 20389 as it is out of bounds
# Skipping user_id 24888 as it is out of bounds
# Skipping user_id 11857 as it is out of bounds
# Skipping user_id 23011 as it is out of bounds
# Skipping user_id 9295 as it is out of bounds
# Skipping user_id 17392 as it is out of bounds
# Skipping user_id 13392 as it is out of bounds
# Skipping user_id 16413 as it is out of bounds
# Skipping user_id 13783 as it is out of bounds
# Skipping user_id 12584 as it is out of bounds
# Skipping user_id 19631 as it is out of bounds
# Skipping user_id 12072 as it is out of bounds
# Skipping user_id 13544 as it is out of bounds
# Skipping user_id 8999 as it is out of bounds
# Skipping user_id 14686 as it is out of bounds
# Skipping user_id 20565 as it is out of bounds
# Skipping user_id 18357 as it is out of bounds
# Skipping user_id 16211 as it is out of bounds
# Skipping user_id 10425 as it is out of bounds
# Skipping user_id 9516 as it is out of bounds
# Skipping user_id 15335 as it is out of bounds
# Skipping user_id 15104 as it is out of bounds
# Skipping user_id 24014 as it is out of bounds
# Skipping user_id 7821 as it is out of bounds
# Skipping user_id 18245 as it is out of bounds
# Skipping user_id 14756 as it is out of bounds
# Skipping user_id 26300 as it is out of bounds
# Skipping user_id 19510 as it is out of bounds
# Skipping user_id 8075 as it is out of bounds
# Skipping user_id 9256 as it is out of bounds
# Skipping user_id 12656 as it is out of bounds
# Skipping user_id 12145 as it is out of bounds
# Skipping user_id 26730 as it is out of bounds
# Skipping user_id 28365 as it is out of bounds
# Skipping user_id 19724 as it is out of bounds
# Skipping user_id 23911 as it is out of bounds
# Skipping user_id 28143 as it is out of bounds
# Skipping user_id 18392 as it is out of bounds
# Skipping user_id 17273 as it is out of bounds
# Skipping user_id 8163 as it is out of bounds
# Skipping user_id 11024 as it is out of bounds
# Skipping user_id 18204 as it is out of bounds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/users/k2369089/SKKU/GCN.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     user_ids = list(unique_users)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>     num_recommendations = 10
# ---> <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     recommendations = generate_recommendations(model, node_features, adj, user_ids, num_recommendations)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     recall = calculate_recall(recommendations, ground_truth)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> Loss = total_loss / len(dataloader)
#
# /scratch/users/k2369089/SKKU/GCN.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     scores = torch.sum(embeddings[user_id] * embeddings[item_ids], dim=1)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     _, top_indices = torch.topk(scores, num_recommendations)
# ---> <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     recommended_items = [item_ids[i].item() for i in top_indices]  # Converting tensor indices to Python integers
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     recommendations[user_id] = set(recommended_items)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> return recommendations
#
# /scratch/users/k2369089/SKKU/GCN.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     scores = torch.sum(embeddings[user_id] * embeddings[item_ids], dim=1)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     _, top_indices = torch.topk(scores, num_recommendations)
# ---> <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     recommended_items = [item_ids[i].item() for i in top_indices]  # Converting tensor indices to Python integers
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     recommendations[user_id] = set(recommended_items)
#      <a href='vscode-notebook-cell://tunnel%2Btemp_gpu_node/scratch/users/k2369089/SKKU/GCN.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> return recommendations
#
# KeyboardInterrupt:
